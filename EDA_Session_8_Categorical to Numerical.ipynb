# %% [markdown]
# # 10-06-2024

# %% [markdown]
# **Categorical to Numerical**
#
# - It is very important to convert categorical data to numerical data
#
# - Beacause in Machine learning models the input is in the form numbers
#
# - ML models developed by maths , so passing text data not works
#
# - we have different types of methods are there
#
#      - i) map method
#      - ii) np.where
#      - iii) One hot encode
#      - iv) Lable Encoder

# %% [markdown]
# **Import the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **read the data**

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")

# %%
# Categorical columns
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **map**
# - first get the unique lables for each column
# - create a dictionary by providing a values to each label
# - for example case status has two lables, we are providing two values
#     - Assign 0 for Certified
#     - Assign 1 for Denied

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Denied':1, 'Certified':0}
d
# Out:
# {'Denied': 1, 'Certified': 0}

# %% [markdown]
# **How to create a column**

# %%
visa_df['case_status_new']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# read the data again #read data again (only read) (reading data again means restarting)
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")
d={'Denied':1, 'Certified':0}
visa_df['case_status_new']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d2={'Y':1,'N':0}
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d2)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **task**
# - read data again
# - apply for loop
# - iterate through columns
# - get the count of unque lables
# - Create a dictionary
# - apply into map

# %%
# step 1
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df['case_status'].unique())
# Out:
# 2

# %%
lables=list(visa_df['case_status'].unique())
values=[i for i in range(len(lables))]
values
# Out:
# [0, 1]

# %%
dict(zip(lables,values))
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    lables=list(visa_df[i].unique())
    values=[i for i in range(len(lables))]
    d=dict(zip(lables,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Label encoder**
#
# - Label encoder is a package under **sickit learn**
#
# - sickit learn is heart of Machine Learning
#
# - Inside sickit learn we have a methos called **Preprocessing**
#
# - under preprocessing we have **LableEncoder**
#
# - sickit learn we wil write as **sklearn**
#
# - any sklearn package we have 3 steps
#
#      - step-1: Read the package
#      - step-2: save the package
#      - step-3: apply the fit transform

# %%
# read the data
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")

# %%
# step-1 : Read the package
from sklearn.preprocessing import LabelEncoder

# step-2: save the package
le=LabelEncoder()

# step-3: apply fit transform
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")
cols=visa_df.select_dtypes(include='object').columns

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])

visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")

from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

visa_df['case_status']=le.fit_transform(visa_df['case_status'])

print(visa_df['case_status'].values) 
print(le.inverse_transform(visa_df['case_status']))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# **LAbleEncoder will use most of the time**

# %% [markdown]
# **np.where**
# - np.where is applicable only for binary
# - np.where will take 3 arguments
#      - condition
#      - True value
#      - False value

# %% [markdown]
# $senario$
# - For example case status value equal to certified replace with zero
# - otherwise(denied) replace with 1

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # 11-06-2024

# %% [markdown]
# **One hot encoder**
#
# - One hot means if one is ON another one is OFF
# - ON represents with 1 , OFF rpresents with 0
# - for example case status has two unque lables
#      - Denied
#      - Certified
# - If we apply one hot encoder on case status column it will create two extra columns like
#    - case_status_Denied
#    - case_status_Certified

# %% [markdown]
# |case_status | case_status_Denied | case_status_Certified|
# |-------------|-----|-----|
# |Denied |            1      |               0|
# |Certified |         0       |              1|

# %% [markdown]
# **Advantages**
# - In Machine learning we have one important property is **Independent of variables**
# - Machine learning models expects variables are **independent to each other**
# - on hot coder creating new columns, the new column are **Independent to each other**
# - Independent variables mean sboth variables have **90 degrees phase shift**
# - 90 degrees phase shift also called as **perpendicular to each other**
# - perpendicular means **orthogonal each other**

# %% [markdown]
# **Disadvantages**
# - One hot encoder creates new columns equal to number of unique lables
# - If number of unique lables increase , new columns also increase
# - The more columns leads data is more
# - Then data is more the complexity will increase
# - Complexity increases more computation power required
# - Also time also increase
# - The entire process named as **Curse of dimentionality**

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - Read the data again
# - choose one column
# - apply pd.get_dummies

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")

# %%
pd.get_dummies(visa_df['case_status'])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(visa_df['case_status'],dtype='int')
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %% [markdown]
# **Note**
# - Always drop the id column (no use of ids)
# - Read again drop it

# %%
visa_df=pd.read_csv(r"C:\Users\keert\Documents\DATA SCIENCE\nareshit\datafiles\Visadataset - Visadataset.csv")
visa_df.drop('case_id',axis=1,inplace=True)
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# - Generally we will prefer LabelEncoder
# - One hot encoder when categorical data has less unique lables
